# %%
import pandas as pd
import matplotlib as plt
import matplotlib as mpl
import numpy as py
#df = pd.read_csv(r'C:\Users\barba\OneDrive\Documents\Cancer.csv')

#print(df)

df = pd.read_excel(r'C:\Users\barba\OneDrive\Documents\Breast_Cancer\Data\Cancer_Data.xlsx')

print(df)
# Out:
#                 STATE  ALL CASES  FEMALEBREAST UTERINE CERVIX  COLON & RECTUM  \
# 0             Alabama      30210          4280            240            2510
# 1              Alaska       3250           530             b              320
# 2             Arizona      39970          6110            290            3150
# 3            Arkansas      18610          2440            160            1530
# 4          California     189220         31720           1640           15970
# 5            Colorado      28480          4730            190            2140
# 6         Connecticut      22810          3550            120            1550
# 7            Delaware       7080          1010             b              500
# 8   Dist. of Columbia       3440           620             b              250
# 9             Florida     152600         20920           1230           11490
# 10            Georgia      58970          9170            490            4970
# ...

# %%
import pandas as pd
import matplotlib as plt
import matplotlib as mpl
import numpy as py

excel_file = pd.ExcelFile(r'C:\Users\barba\OneDrive\Documents\Breast_Cancer\Data\Cancer_Data.xlsx')
excel_df = excel_file.parse()
type(excel_file)

#excel_df = excel_file.parse()

#excel_df.head()

#post_excel = pd.read_excel(r'C:\Users\barba\OneDrive\Documents\Breast_Cancer\Data\Cancer_Data.xlsx')

#dir(post_excel)

#pd.read_excel(r'C:\Users\barba\OneDrive\Documents\Breast_Cancer\Data\Cancer_Data.xlsx', usecols=[0, 3]).columns

#pd.read_excel(r'C:\Users\barba\OneDrive\Documents\Breast_Cancer\Data\Cancer_Data.xlsx', usecols='A:C').columns

#excel_file.sheet_names

#post_dict = pd.read_excel(r'C:\Users\barba\OneDrive\Documents\Breast_Cancer\Data\Cancer_Data.xlsx', sheet_name=None)

#pd.read_excel(r'C:\Users\barba\OneDrive\Documents\Breast_Cancer\Data\Cancer_Data.xlsx', sheet_name='Sheet3').head()

#print()



#df = pd.read_excel(r'C:\Users\barba\OneDrive\Documents\Breast_Cancer\Data\Cancer_Data.xlsx')


#Decide what data to plot
def read_file (STATE = ['Michigan','Kentucky','Ohio','California','Texas']):'state'

print(read_file)
        
#df = pd.DataFrame('rows',columns=['STATE','FEMALEBREAST'])

#Plot data
#df.plot(kind = 'bar', x = 'STATE', y = 'FEMALEBREAST',  
        #color = 'pink', title = 'Breast Cancer per State')
# Out:
# <function read_file at 0x00000173DBD41120>

# %%
import pandas as pd
import matplotlib as plt
import matplotlib as mpl
import numpy as py
#df = pd.read_csv(r'C:\Users\barba\OneDrive\Documents\Cancer.csv')

#print(df)

df = pd.read_excel(r'C:\Users\barba\OneDrive\Documents\Breast_Cancer\Data\Cancer_Data.xlsx')

#print(df)

df.head()

def my_function(STATE = ['Michigan','Kentucky','Ohio','California','Texas']):
        
    print(STATE)

my_function()

STATE_and_FEMALEBREAST = df.loc[:,['STATE','FEMALEBREAST']]

#def my_function(STATE_FEMALEBREAST = [['STATE','FEMALEBREAST']]):
    #print(STATE_FEMALEBREAST)

#my_function()

desired_data = STATE_and_FEMALEBREAST.loc[STATE_and_FEMALEBREAST['STATE'] .isin(['California','Michigan','Kentucky','Ohio','Texas'])]

print(desired_data)

#count(STATES)

#Return the number of  STATES in the list.
# Out:
# ['Michigan', 'Kentucky', 'Ohio', 'California', 'Texas']
#          STATE  FEMALEBREAST
# 4   California         31720
# 17    Kentucky          3950
# 22    Michigan          8900
# 35        Ohio         10610
# 43       Texas         21040

# %%
#check for null values
df.isnull().sum()
# Out:
# STATE                   0
# ALL CASES               0
# FEMALEBREAST            0
# UTERINE CERVIX          0
# COLON & RECTUM          0
# UTERINE CORPUS          0
# LEUKEMIA                0
# LUNG & BRONCHUS         0
# MELANOMA OF THE SKIN    0
# NON-HODGKIN LYMPHOMA    0
# PROSTATE                0
# URINARY BLADDE          0
# dtype: int64

# %%
#replace b with value of 0.
df2 = df.replace(to_replace='b ', value=0)
df2
# Out:
#                 STATE  ALL CASES  FEMALEBREAST  UTERINE CERVIX  \
# 0             Alabama      30210          4280             240
# 1              Alaska       3250           530               0
# 2             Arizona      39970          6110             290
# 3            Arkansas      18610          2440             160
# 4          California     189220         31720            1640
# 5            Colorado      28480          4730             190
# 6         Connecticut      22810          3550             120
# 7            Delaware       7080          1010               0
# 8   Dist. of Columbia       3440           620               0
# 9             Florida     152600         20920            1230
# 10            Georgia      58970          9170             490
# 11             Hawaii       7730          1430              60
# 12              Idaho      10440          1490              70
# 13           Illinois      75350         11340             530
# ...
