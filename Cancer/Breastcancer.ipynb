# %%
import pandas as pd
import matplotlib as plt
import matplotlib as mpl
import numpy as py
#df = pd.read_csv(r'C:\Users\barba\OneDrive\Documents\Cancer.csv')

#print(df)

df = pd.read_excel(r'C:\Users\barba\OneDrive\Documents\Breast_Cancer\Data\Cancer_Data.xlsx')

print(df)
# Out:
#                 STATE  ALL CASES  FEMALEBREAST UTERINE CERVIX  COLON & RECTUM  \
# 0             Alabama      30210          4280            240            2510
# 1              Alaska       3250           530             b              320
# 2             Arizona      39970          6110            290            3150
# 3            Arkansas      18610          2440            160            1530
# 4          California     189220         31720           1640           15970
# 5            Colorado      28480          4730            190            2140
# 6         Connecticut      22810          3550            120            1550
# 7            Delaware       7080          1010             b              500
# 8   Dist. of Columbia       3440           620             b              250
# 9             Florida     152600         20920           1230           11490
# 10            Georgia      58970          9170            490            4970
# ...

# %%
#check for null values
df.isnull().sum()
# Out:
# STATE                   0
# ALL CASES               0
# FEMALEBREAST            0
# UTERINE CERVIX          0
# COLON & RECTUM          0
# UTERINE CORPUS          0
# LEUKEMIA                0
# LUNG & BRONCHUS         0
# MELANOMA OF THE SKIN    0
# NON-HODGKIN LYMPHOMA    0
# PROSTATE                0
# URINARY BLADDE          0
# dtype: int64

# %%
#replace b with value of 0.
df = df.drop(labels=51, axis=0)
df2 = df.replace(to_replace='b ', value=0)
df2
# Out:
#                 STATE  ALL CASES  FEMALEBREAST  UTERINE CERVIX  \
# 0             Alabama      30210          4280             240
# 1              Alaska       3250           530               0
# 2             Arizona      39970          6110             290
# 3            Arkansas      18610          2440             160
# 4          California     189220         31720            1640
# 5            Colorado      28480          4730             190
# 6         Connecticut      22810          3550             120
# 7            Delaware       7080          1010               0
# 8   Dist. of Columbia       3440           620               0
# 9             Florida     152600         20920            1230
# 10            Georgia      58970          9170             490
# 11             Hawaii       7730          1430              60
# 12              Idaho      10440          1490              70
# 13           Illinois      75350         11340             530
# ...

# %%
import pandas as pd
import matplotlib as plt
import matplotlib as mpl
import numpy as py

round(df['FEMALEBREAST'].mean(),2)
# Out:
# 5644.31

# %%
df['FEMALEBREAST'].sum()
# Out:
# 287860

# %%
def print_columns(columns, df2):
        df = df2.loc[df2['columns']=='columns']
        
        print(df)


print('The total sum of equals')

df[input ('What column do you want:')].sum()
# Out:
# The total sum of equals
# 287860

# %%
df.describe()
# Out:
#            ALL CASES  FEMALEBREAST  COLON & RECTUM  UTERINE CORPUS  \
# count      51.000000     51.000000       51.000000       51.000000
# mean    37608.039216   5644.313725     2961.764706     1293.333333
# std     39666.960661   6127.491250     3206.549364     1413.061452
# min      3140.000000    460.000000      240.000000      100.000000
# 25%     10735.000000   1545.000000      820.000000      370.000000
# 50%     28480.000000   3970.000000     2140.000000      830.000000
# 75%     42410.000000   6865.000000     3355.000000     1465.000000
# max    189220.000000  31720.000000    15970.000000     7110.000000
#
#           LEUKEMIA  LUNG & BRONCHUS  MELANOMA OF THE SKIN  \
# count    51.000000        51.000000             51.000000
# mean   1188.823529      4641.764706           1956.470588
# std    1374.895846      4488.066713           2038.891683
# min      90.000000       330.000000             70.000000
# 25%     340.000000      1185.000000            645.000000
# ...

# %%
df['FEMALEBREAST'].median()
# Out:
# 3970.0

# %%
df['FEMALEBREAST'].count()
# Out:
# 51

# %%
import pandas as pd
import matplotlib as plt
import matplotlib as mpl
import numpy as py

#df = pd.read_csv(r'C:\Users\barba\OneDrive\Documents\Cancer.csv')

#print(df)

df = pd.read_excel(r'C:\Users\barba\OneDrive\Documents\Breast_Cancer\Data\Cancer_Data.xlsx')

#print(df)

df.head()

def print_states(STATE, Cancer, df2):
        df = df2.loc[df2['STATE']==STATE,['FEMALEBREAST']]
        
        print(df)


Look_State = input ('What stete do you want:')

print("The number of breast cancer cases in " + Look_State + "!")

print_states(Look_State, Look_State, df,)
#print()
# Out:
# The number of breast cancer cases in Ohio!
#     FEMALEBREAST
# 35         10610

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as py

df = pd.read_excel(r'C:\Users\barba\OneDrive\Documents\Breast_Cancer\Data\Cancer_Data.xlsx')

df = df.drop(labels=51, axis=0)

def print_states(STATE, Cancer, df2):
        df = df2.loc[df2['STATE']==STATE,['FEMALEBREAST']]
        
        print(df)

df.plot(kind = 'bar', x = 'STATE', y = 'FEMALEBREAST',  
        color = 'red', title = 'Breast Cancer per State')

plt.show(df.plot)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as py

df = pd.read_excel(r'C:\Users\barba\OneDrive\Documents\Breast_Cancer\Data\Cancer_Data.xlsx')


Look_State = input (' What stete do you want: ') 
print(Look_State)

print("The number of breast cancer cases in " + Look_State + "!")

df = df.loc[df['STATE']==Look_State,['FEMALEBREAST']]
#print("KEYS",df.keys())
print(df)




df.plot(kind = 'bar', y = 'FEMALEBREAST',
        color = 'blue', title = 'Breast Cancer per State')

plt.show(df.plot)
# Out:
# Michigan
# The number of breast cancer cases in Michigan!
#     FEMALEBREAST
# 22          8900

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as py

df = pd.read_excel(r'C:\Users\barba\OneDrive\Documents\Breast_Cancer\Data\Cancer_Data.xlsx')


Look_State = input('What state do you want:')
print(Look_State)

print("The number of breast cancer cases in " + Look_State + "!")


df = df.loc[df['STATE']==Look_State,['FEMALEBREAST']]
#print("KEYS",df.keys())
print(df)

df.plot(kind = 'bar', y = 'FEMALEBREAST',
        color = 'pink', title = 'Breast Cancer per State')

plt.show(df.plot)
# Out:
# Michigan
# The number of breast cancer cases in Michigan!
#     FEMALEBREAST
# 22          8900
